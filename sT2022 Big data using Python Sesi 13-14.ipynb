# %% [markdown]
# # The Object Oriented Programming

# %%
x = 1
print(type(x))
# Out:
# <class 'int'>

# %%
print(type("Hello"))
# Out:
# <class 'str'>

# %%
def hello():
    print("Hello")

print(type(hello))
# Out:
# <class 'function'>

# %%
#define class dog
class Dog:
    def suara(self):
        print("Mengonggong")
        
#create an object
d = Dog()
d.suara()
print(type(d))
# Out:
# Mengonggong
# <class '__main__.Dog'>

# %%
#define class dog
class Dog:
    def sleep(self, x):
        return "zzzz" + " " + x
    def suara(self):
        print("Mengonggong")
        
#create an object
d = Dog()
print(d.sleep("bruurr"))
# Out:
# zzzz bruurr

# %%
#define class dog
class Dog:
    def __init__(self,name, age):
        self.name = name
        self.age = age
        
    def sleep(self, x):
        return "zzzz" + " " + x
    def suara(self):
        print("Mengonggong")
    
    def get_name(self):
        return self.name
    def get_age(self):
        return self.age
        
#create an object
d = Dog("Boby", 14)
print(d.get_age())

d2 = Dog("Bill", 10)
print(d2.get_age())
# Out:
# 14
# 10

# %%
#define class dog
class Dog:
    def __init__(self,name, age):
        self.name = name
        self.age = age
        
    def get_name(self):
        return self.name
    def get_age(self):
        return self.age
    def set_age(self,age):
        self.age = age
        
#create an object
d = Dog("Boby", 14)
print(d.get_age())
d.set_age(13)
print(d.get_age())
# Out:
# 14
# 13

# %% [markdown]
# Exercise, buat dua kelas, **Student** (name age, grade, fungsi get_grade) dan **Course**
# (nama, max_students, fungsi add_student, average_garde)

# %%
class Student:
    def __init__(self, name, age, grade):
        self.name = name
        self.age = age
        self.grade = grade
        
    def get_grade(self):
        return self.grade
    
    def get_name(self):
        return self.name
    
class Course:
    def __init__(self, name, max_students):
        self.name = name
        self.max_students = max_students
        self.students = []
    
    def add_student(self, std):
        if len(self.students) < self.max_students:
            self.students.append(std)
            return True
        return print("Kuota habis untuk ",std.get_name())
    
    def get_average_grade(self):
        val = 0
        for std in self.students:
            val += std.get_grade()
        return val/ len(self.students)
    
s1 = Student("Andi", 18, 96)
s2 = Student("Budi", 18, 70)
s3 = Student("Anto", 18, 50)

MK = Course("Sejarah", 2)
MK.add_student(s1)
MK.add_student(s2)
MK.add_student(s3)
print(MK.students[1].name)
print("Average grade:", MK.get_average_grade())
# Out:
# Kuota habis untuk  Anto
# Budi
# Average grade: 83.0

# %% [markdown]
# Python Inheritance

# %%
class Pet:
    def __init__(self,name, age):
        self.name = name
        self.age = age
    
    def show(self):
        print(f"saya {self.name} dan umur saya {self.age}")
    
    def suara(self):
        print("Saya tidak tahu bagaimana berbicara")

class Dog(Pet): 
    def suara(self):
        print("Guk Guk Guk")
        
class Cat(Pet):
    def suara(self):
        print("Meow meow")
        
#p = Pet("Kuma", 10)
#p.show()
#p.suara()

#d = Dog("Boby", 12)
#d.show()
#d.suara()

c = Cat("Pinky", 9)
c.show()
c.suara()
# Out:
# saya Pinky dan umur saya 9
# Meow meow

# %%
class Person:
    number_of_people = 0
    
    def __init__(self, name):
        self.name  = name
        Person.add_person()
        
    @classmethod
    def number_of_people_(cls):
        return cls.number_of_people
    
    @classmethod
    def add_person(cls):
        cls.number_of_people +=1
        
p1 = Person("Budi")
p2 = Person("Andi")

print(Person.number_of_people_())
# Out:
# 2

# %%
class Math:
    
    @staticmethod
    def add6(x):
        return x + 6
    
    @staticmethod
    def add10(x):
        return x + 10
    
print(Math.add10(5))
# Out:
# 15

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# ![image.png](attachment:image.png)
